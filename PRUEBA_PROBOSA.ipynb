# %% [markdown]
# <a href="https://colab.research.google.com/github/leodsv2012-stack/AUIDCHVLIDSCGBLIswedf/blob/main/PRUEBA_PROBOSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ZIMBABWE SHULK")
# Out:
# ZIMBABWE KIRBY

# %%
jugador ="Shulk"
print(jugador,"Ha entrado a Zimbabwe")
jugador2 = "Kirby"
print(jugador2,"se ha caido de Zimbabwe")
# Out:
# Shulk Ha entrado a Zimbabwe
# Kirby se ha caido de Zimbabwe
